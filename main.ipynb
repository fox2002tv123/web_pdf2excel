# %%
'''
Author: bob
Date: 2022-05-24 16:59:52
LastEditors: bob
LastEditTime: 2022-05-24 16:59:58
FilePath: \任务22-开发网络版对账单转换工具\main.ipynb
Description: 使用python编写的网络版对账单转换工具

Copyright (c) 2022 by bob, All Rights Reserved. 
'''
# Out:
# '\nAuthor: bob\nDate: 2022-05-24 16:59:52\nLastEditors: bob\nLastEditTime: 2022-05-24 16:59:58\nFilePath: \\任务22-开发网络版对账单转换工具\\main.ipynb\nDescription: 使用python编写的网络版对账单转换工具\n\nCopyright (c) 2022 by bob, All Rights Reserved. \n'

# %%
# open读取txt文件

with open('data.txt', 'r',encoding='utf-8') as f:
    data = f.read()
data
# Out:
# '209823 LBVKY9109KSU85151 A5AN43\n6137241300 61315A4A4E8 16,548.67 100.00 25.00- 1 12,411.50 893.63 1,729.67 15,034.80\n6137241300 6131822 31.90 100.00 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付12,411.50 63.80 893.63 1,737.96 15,106.89\n284822 LBV5T3102HSJ84822 A5APXK\n9999001386 4 782.99 1 782.99 101.79 884.78\n_____________________________________________________________________________________________________________________________________\n* 赔付782.99 101.79 884.78\n209852 LBV31DU02NS367308 A5ARO6\n9987000086 0000009 31.90 9 287.10 37.32 324.42\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n9987000086 6590600 31.90 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付382.80 49.76 432.56\n209851 LBV6R4105NM338027 A5ARO7\n9987000086 0000009 31.90 9 287.10 37.32 324.42\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n9987000086 6590600 31.90 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付382.80 49.76 432.56\n209850 LBV6R4109NM309985 A5ARO8\n9987000086 0000009 31.90 9 287.10 37.32 324.42\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n9987000086 6590600 31.90 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付382.80 49.76 432.56\n经销商代码: 33500\n成都宝悦汽车有限公司\n成都市金牛区金科南路3号\n610036 Chengdu\nReport of admitted Warrant y-Claims Page: 1\nDate: 2022.05.04\nCredit Note Number 1273470 经销商代码: 33500 Copy!Original created on 2022.05.02\n工单号底盘号保修单再申请旧保修单号标题决定代码\n故障代码项目价格比率折扣数量配件工时外包处理费税费(13%) 合计\n决定代码/项目\n209848 LBV6R4101NM338025 A5ARO9\n9987000086 0000009 31.90 9 287.10 37.32 324.42\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n9987000086 6590600 31.90 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付382.80 49.76 432.56\n209846 LBV61AF00NS372516 A5AROA\n9987000086 0000009 31.90 10 319.00 41.47 360.47\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n9987000086 6590600 31.90 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付414.70 53.91 468.61\n209845 LBV31DU08NS360072 A5AROB\n9987000086 0000009 31.90 9 287.10 37.32 324.42\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n9987000086 6590600 31.90 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付382.80 49.76 432.56\n209844 LBV21AF03NS350623 A5AROC\n9987000086 0000009 31.90 10 319.00 41.47 360.47\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n9987000086 6590600 31.90 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付414.70 53.91 468.61\n209842 LBV41DU07NS403174 A5AROD\n9987000086 0000009 31.90 9 287.10 37.32 324.42\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n9987000086 6590600 31.90 2 63.80 8.29 72.09\n_____________________________________________________________________________________________________________________________________\n* 赔付382.80 49.76 432.56\n209841 LBVHY5108NM350903 A5AROE\n9987000086 0000009 31.90 9 287.10 37.32 324.42\n9987000086 0000742 31.90 1 31.90 4.15 36.05\n_____________________________________________________________________________________________________________________________________\nReport of admitted Warrant y-Claims Page: 2\nDate: 2022.05.04\nCredit Note Number 1273470 经销商代码: 33500 Copy!Original created on 2022.05.02\n工单号底盘号保修单再申请旧保修单号标题决定代码\n故障代码项目价格比率折扣数量配件工时外包处理费税费(13%) 合计\n决定代码/项目\n* 赔付319.00 41.47 360.47 ...

# %%
# # 预留-数据data提取的第二种方法
# data=input('请输入数据：')
# data

# %%
# 1.通过re模块提取数据-表头
import re
p=r'(\d{5,6}) (\S{17}) (\S{6})'
res_head=re.findall(p,data)
res_head
# Out:
# [('209823', 'LBVKY9109KSU85151', 'A5AN43'),
#  ('284822', 'LBV5T3102HSJ84822', 'A5APXK'),
#  ('209852', 'LBV31DU02NS367308', 'A5ARO6'),
#  ('209851', 'LBV6R4105NM338027', 'A5ARO7'),
#  ('209850', 'LBV6R4109NM309985', 'A5ARO8'),
#  ('209848', 'LBV6R4101NM338025', 'A5ARO9'),
#  ('209846', 'LBV61AF00NS372516', 'A5AROA'),
#  ('209845', 'LBV31DU08NS360072', 'A5AROB'),
#  ('209844', 'LBV21AF03NS350623', 'A5AROC'),
#  ('209842', 'LBV41DU07NS403174', 'A5AROD'),
#  ('209841', 'LBVHY5108NM350903', 'A5AROE'),
#  ('209840', 'LBV6R4107NM348672', 'A5AROF'),
#  ('209839', 'LBV61AF0XNS360891', 'A5AROG'),
#  ('209837', 'LBV61AF00NS397240', 'A5AROH'),
#  ('209836', 'LBVHY510XNM350885', 'A5AROI'),
#  ('209830', 'LBVYH340XNM354449', 'A5AROK'),
#  ('209829', 'LBV21AF05NS355337', 'A5AROL'),
#  ('209826', 'LBV21AF02NS390496', 'A5AROM'),
#  ('209825', 'LBV5U5409NM349818', 'A5ARON'),
#  ('209824', 'LBV61AF09NS397253', 'A5AROO'),
#  ('209893', 'LBVKY9107LSU91046', 'A5AS9X'),
#  ('209892', 'LBV61AF08MSZ47220', 'A5AS9Y'),
#  ('209891', 'LBV7Y4100MS060090', 'A5AS9Z'),
#  ('209890', 'LBV6P4109LMS17925', 'A5ASA0'),
#  ('209885', 'LBV2A3406HMJ20825', 'A5ASA2'),
#  ('209882', 'LBV21AF0XMSY54116', 'A5ASA3'),
#  ('209881', 'LBV61AF02MS001114', 'A5ASA4'),
#  ('209880', 'LBV7Y0102MS060343', 'A5ASA5'),
#  ('209879', 'LBV8W3101KMP23382', 'A5ASA6'),
#  ('209878', 'LBVTZ0100KSU01831', 'A5ASA7'),
#  ('209876', 'LBVHY3101LMX08148', 'A5ASA8'),
#  ('209872', 'LBVKY5107LST56867', 'A5ASA9'),
#  ('209870', 'LBVTZ0101KSU03894', 'A5ASAA'),
#  ('209869', 'LBV5F340XLMX07259', 'A5ASAB'),
#  ('209868', 'LBV6P4100LMW05240', 'A5ASAC'),
#  ('209867', 'LBV6R410XMM043147', 'A5ASAD'),
#  ('209866', 'LBV61BE04MM010733', 'A5ASAE'),
#  ('209864', 'LBV21AF08MS035931', 'A5ASAF'),
#  ('209863', 'LBV61BE02NM340646', 'A5ASAG'),
#  ('209861', 'LBV61BE09NM352650', 'A5ASAH'),
#  ('209860', 'LBV31DU04NS378682', 'A5ASAI'),
#  ('209853', 'LBV41DU04NS398158', 'A5ASAJ'),
#  ('209859', 'LBV31DU08NS378250', 'A5ASAK'),
#  ('209857', 'LBV61BE06NM355571', 'A5ASAL'),
#  ('209855', 'LBV21BD01NS250450', 'A5ASBJ'),
#  ('209854', 'LBV11DU0XNS376684', 'A5ASCH'),
#  ('324225', 'LBV5S3102FSM24225', 'A5AT7N'),
#  ('209895', 'LBV7Y0103MS037346', 'A5AT7X'),
#  ('209910', 'LBVHZ3103KMR49012', 'A5ATV6'),
#  ('209909', 'LBV21BD00MS195116', 'A5ATV7'),
#  ('209908', 'LBV21BD05NS205995', 'A5ATV8'),
#  ('209905', 'LBVKY9100KSU89962', 'A5ATV9'),
#  ('209903', 'LBVHZ3102KMR44657', 'A5ATVB'),
#  ('209902', 'LBV8W3108KMP37862', 'A5ATVC'),
#  ('209897', 'LBV6R4106MM155069', 'A5ATVE'),
#  ('209896', 'LBVYH1403LMY27853', 'A5ATVF'),
#  ('209912', 'LBV61AF03MSZ12925', 'A5ATVG')]

# %%
# 2.通过re模块提取数据-表体
# import re
p=r'\*( 赔付)(\S*) ?(\S*) ?(\S*) ?(\S*) ?(\S*) ?(\S*) ?(\S*)'
res_body=re.findall(p,data)
res_body
# Out:
# [(' 赔付', '12,411.50', '63.80', '893.63', '1,737.96', '15,106.89', '', ''),
#  (' 赔付', '782.99', '101.79', '884.78', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '414.70', '53.91', '468.61', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '414.70', '53.91', '468.61', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '319.00', '41.47', '360.47', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '414.70', '53.91', '468.61', '', '', '', ''),
#  (' 赔付', '414.70', '53.91', '468.61', '', '', '', ''),
#  (' 赔付', '319.00', '41.47', '360.47', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '414.70', '53.91', '468.61', '', '', '', ''),
#  (' 赔付', '414.70', '53.91', '468.61', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '414.70', '53.91', '468.61', '', '', '', ''),
#  (' 赔付', '4,500.56', '669.90', '324.04', '714.29', '6,208.79', '', ''),
#  (' 赔付', '143.01', '130.96', '550.51', '107.19', '931.67', '', ''),
#  (' 赔付', '143.01', '130.96', '550.33', '107.16', '931.46', '', ''),
#  (' 赔付', '1,695.18', '1,276.00', '122.05', '402.11', '3,495.34', '', ''),
#  (' 赔付', '2,732.67', '1,116.50', '478.22', '562.57', '4,889.96', '', ''),
#  (' 赔付', '255.20', '33.18', '288.38', '', '', '', ''),
#  (' 赔付', '143.01', '130.96', '479.56', '97.96', '851.49', '', ''),
#  (' 赔付', '143.01', '130.96', '479.56', '97.96', '851.49', '', ''),
#  (' 赔付', '95.70', '12.44', '108.14', '', '', '', ''),
#  (' 赔付', '863.84', '287.10', '62.20', '157.71', '1,370.85', '', ''),
#  (' 赔付', '255.20', '33.18', '288.38', '', '', '', ''),
#  (' 赔付',
#   '20,235.89',
#   '1,818.30',
#   '621.49',
#   '1,456.99',
#   '3,137.25',
#   '27,269.92',
#   ''),
#  (' 赔付', '845.93', '287.10', '60.91', '155.21', '1,349.15', '', ''),
#  (' 赔付', '9,092.92', '255.20', '654.69', '1,300.37', '11,303.18', '', ''),
#  (' 赔付', '929.20', '478.50', '66.90', '191.69', '1,666.29', '', ''),
#  (' 赔付', '143.01', '130.96', '550.51', '107.19', '931.67', '', ''),
#  (' 赔付', '143.01', '130.96', '518.48', '103.02', '895.47', '', ''),
#  (' 赔付', '143.01', '130.96', '508.61', '101.74', '884.32', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '446.60', '58.06', '504.66', '', '', '', ''),
#  (' 赔付', '382.80', '49.76', '432.56', '', '', '', ''),
#  (' 赔付', '697.00', '90.61', '787.61', '', '', '', ''),
#  (' 赔付', '143.01', '130.96', '479.56', '97.96', '851.49', '', ''),
#  (' 赔付', '337.67', '127.60', '24.31', '63.65', '553.23', '', ''),
#  (' 赔付', '143.01', '130.96', '550.24', '107.15', '931.36', '', ''),
#  (' 赔付', '143.01', '130.96', '550.24', '107.15', '931.36', '', ''),
#  (' 赔付', '3,236.79', '510.40', '233.04', '517.43', '4,497.66', '', ''),
#  (' 赔付', '1,043.25', '1,116.50', '75.12', '290.54', '2,525.41', '', ''),
#  (' 赔付', '5,189.37', '1,244.10', '373.63', '884.91', '7,692.01', '', ''),
#  (' 赔付', '143.01', '130.96', '550.33', '107.16', '931.46', '', ''),
#  (' 赔付', '143.01', '130.96', '439.69', '92.78', '806.44', '', ''),
#  (' 赔付', '747.61', '314.30', '550.51', '209.62', '1,822.04', '', '')]

# %%
# 3.通过re模块提取数据-对账单序列号
# import re
p=r'Credit Note Number (\d{7})'
res_number=re.findall(p,data)
res_number=res_number[0]
res_number
# Out:
# '1273470'

# %%
# 4.通过re模块提取数据-对账单日期
# import re
p=r'created on (\S{10})'
res_date=re.findall(p,data)
res_date=res_date[0]
res_date
# Out:
# '2022.05.02'

# %%
# 5.判断国产还是进口
first_char=res_head[0][1][0]
if first_char=='L':
    s='BBA'
else:
    s='GIS'
s
# Out:
# 'BBA'

# %%
# 通过pandas转换成dataframe
import pandas as pd
import numpy as np
df1=pd.DataFrame(res_head,columns=['保修单号','车架号','DWP保修单号'])
df1
df2=pd.DataFrame(res_body,columns=list('A1234567'))
df2
# 合并两个dataframe concat axis=1
df=pd.concat([df1,df2],axis=1)
df

# 去掉',',并转换成float
df.loc[:,'1':'7']=df.loc[:,'1':'7'].applymap(lambda x:str(x).replace(',',''))

# 转换成float
for i in range(1,8):
    df.loc[:,'{}'.format(i)]=pd.to_numeric(df.loc[:,'{}'.format(i)],errors='coerce')

# 添加汇总列
df['总计']=df.loc[:,'1':'7'].max(axis=1)

# 添加各种'对账单序列号','对账单日期'列
df['对账单序列号']=res_number
df['对账单日期']=res_date.replace('.','/')

df.head()
# df.info()
# Out:
#      保修单号                车架号 DWP保修单号    A         1       2       3        4  \
# 0  209823  LBVKY9109KSU85151  A5AN43   赔付  12411.50   63.80  893.63  1737.96
# 1  284822  LBV5T3102HSJ84822  A5APXK   赔付    782.99  101.79  884.78      NaN
# 2  209852  LBV31DU02NS367308  A5ARO6   赔付    382.80   49.76  432.56      NaN
# 3  209851  LBV6R4105NM338027  A5ARO7   赔付    382.80   49.76  432.56      NaN
# 4  209850  LBV6R4109NM309985  A5ARO8   赔付    382.80   49.76  432.56      NaN
#
#           5   6   7        总计   对账单序列号       对账单日期
# 0  15106.89 NaN NaN  15106.89  1273470  2022/05/02
# 1       NaN NaN NaN    884.78  1273470  2022/05/02
# 2       NaN NaN NaN    432.56  1273470  2022/05/02
# 3       NaN NaN NaN    432.56  1273470  2022/05/02
# 4       NaN NaN NaN    432.56  1273470  2022/05/02

# %%
# 写入excel
# 改变列的顺序
alist=['DWP保修单号','保修单号','车架号','对账单序列号','对账单日期','1','2','3','4','5','总计']
# df[alist].to_excel(f'{res_number}DATE{res_date}{s}.xlsx',index=False)

# %% [markdown]
# # 附加功能-找到每个细节

# %%
df.shape
# Out:
# (57, 14)

# %%
# 0.re提取每个特征-生成段落
import re
detail_list=re.findall(r'[^_]+',data)[:-1]
detail_list.__len__()
detail_list[0]
# Out:
# '209823 LBVKY9109KSU85151 A5AN43\n6137241300 61315A4A4E8 16,548.67 100.00 25.00- 1 12,411.50 893.63 1,729.67 15,034.80\n6137241300 6131822 31.90 100.00 2 63.80 8.29 72.09\n'

# %%
# 1是否有零件特征
detail_part=[]
for i in detail_list:
    if re.findall(r'\d{10} \S{11}',i): # 判断是否有零件特征
        detail_part.append(True)
    else:
        detail_part.append(False)
detail_part
detail_part.__len__()
# Out:
# 57

# %%
# 2是否有工时特征
detail_FRU=[]
for i in detail_list:
    if re.findall(r'\d{10} \S{7}',i): # 判断是否有工时特征
        detail_FRU.append(True)
    else:
        detail_FRU.append(False)
detail_FRU
detail_FRU.__len__()
# Out:
# 57

# %%
# 3是否有辅料特征
detail_sublit=[]
for i in detail_list:
    if re.findall(r'\d{10} \S{1} ',i): # 判断是否有辅料特征
        detail_sublit.append(True)
    else:
        detail_sublit.append(False)
# detail_sublit
detail_sublit.__len__()
# Out:
# 57

# %%
# 4是否有 处理费 特征
detail_handcost=[]
for i in detail_list:
    if re.findall(r'\d{9}[^6] \S{11}',i): # DC最后一位不能是6
        detail_handcost.append(True)
    else:
        detail_handcost.append(False)
# detail_handcost
detail_handcost.__len__()
# Out:
# 57

# %%
# 5是否有 税费 特征-都有
detail_tax=[]
for i in detail_list:
        detail_tax.append(True)
detail_tax
detail_tax.__len__()
# Out:
# 57

# %%
# 6是否有 合计特征-都有
detail_total=[]
for i in detail_list:
        detail_total.append(True)
detail_total
detail_total.__len__()
# Out:
# 57

# %%
# 形成一个dataframe
df_detail=pd.DataFrame({'detail_part':detail_part,'detail_FRU':detail_FRU,'detail_sublit':detail_sublit,'detail_handcost':detail_handcost,'detail_tax':detail_tax,'detail_total':detail_total})
df_detail.head()
# Out:
#    detail_part  detail_FRU  detail_sublit  detail_handcost  detail_tax  \
# 0         True        True          False             True        True
# 1        False       False           True            False        True
# 2        False        True          False            False        True
# 3        False        True          False            False        True
# 4        False        True          False            False        True
#
#    detail_total
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True

# %%
# 通过true false 填入数据
import numpy as np
df_detail_res=df_detail.copy()
df_value=df.loc[:,'1':'6']
df_value.head()
for i in range(df_value.shape[0]):
    k=0
    for j in range(df_value.shape[1]):
        if df_detail.iloc[i,j]:
            df_detail_res.iloc[i,j]=df_value.iloc[i,k]
            k+=1
        else:
            df_detail_res.iloc[i,j]=np.nan    

df_detail_res.head()
# Out:
#   detail_part detail_FRU  detail_sublit detail_handcost detail_tax  \
# 0     12411.5       63.8            NaN          893.63    1737.96
# 1         NaN        NaN         782.99             NaN     101.79
# 2         NaN      382.8            NaN             NaN      49.76
# 3         NaN      382.8            NaN             NaN      49.76
# 4         NaN      382.8            NaN             NaN      49.76
#
#   detail_total
# 0     15106.89
# 1       884.78
# 2       432.56
# 3       432.56
# 4       432.56

# %%
# df和df_detail_res合并 axis=1
df_res=pd.concat([df,df_detail_res],axis=1)
df_res.head()
# Out:
#      保修单号                车架号 DWP保修单号    A         1       2       3        4  \
# 0  209823  LBVKY9109KSU85151  A5AN43   赔付  12411.50   63.80  893.63  1737.96
# 1  284822  LBV5T3102HSJ84822  A5APXK   赔付    782.99  101.79  884.78      NaN
# 2  209852  LBV31DU02NS367308  A5ARO6   赔付    382.80   49.76  432.56      NaN
# 3  209851  LBV6R4105NM338027  A5ARO7   赔付    382.80   49.76  432.56      NaN
# 4  209850  LBV6R4109NM309985  A5ARO8   赔付    382.80   49.76  432.56      NaN
#
#           5   6   7        总计   对账单序列号       对账单日期 detail_part detail_FRU  \
# 0  15106.89 NaN NaN  15106.89  1273470  2022/05/02     12411.5       63.8
# 1       NaN NaN NaN    884.78  1273470  2022/05/02         NaN        NaN
# 2       NaN NaN NaN    432.56  1273470  2022/05/02         NaN      382.8
# 3       NaN NaN NaN    432.56  1273470  2022/05/02         NaN      382.8
# 4       NaN NaN NaN    432.56  1273470  2022/05/02         NaN      382.8
#
#    detail_sublit detail_handcost detail_tax detail_total
# 0            NaN          893.63    1737.96     15106.89
# 1         782.99             NaN     101.79       884.78
# 2            NaN             NaN      49.76       432.56
# 3            NaN             NaN      49.76       432.56
# 4            NaN             NaN      49.76       432.56

# %%
# 修改列的名字
df1=df_res.copy()
new_columns=['DWP','CLAIM','VIN','NO','DATE','1','2','3','4','5','TOTAL']
df1.rename(columns=dict(zip(alist,new_columns)),inplace=True)
df1[new_columns].head()
# df1[['TOTAL','detail_total']].head()
(df1['TOTAL']-df1['detail_total']).unique() # 合计和detail_total的差值相等
collect_list=['DWP','CLAIM','VIN','NO','DATE','detail_part','detail_FRU','detail_sublit','detail_handcost','detail_tax','TOTAL']
df1[collect_list].head()
# df1[collect_list].to_excel(f'{res_number}DATE{res_date}{s}.xlsx',index=False)
